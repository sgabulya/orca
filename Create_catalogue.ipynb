# %% [markdown]
# ### Import packages

# %%
import os
import glob
import numpy  as np
import pandas as pd
import librosa
import librosa.display
import matplotlib.pyplot as plt
import ipywidgets as widgets
import soundfile as sf
import yaml
import math
import datetime
import time

# %% [markdown]
# ### Set directory

# %%
directory='/Users/saroltagabulya/git/Orca/'
folders=os.listdir(directory+'call_segments/')
file=[]

# %%
dropdown=widgets.Dropdown(
    options=folders,
    description='Choose folder:',
    disabled=False,
)

def dropdown_eventhandler(change):
    file.clear()
    file.append(change.new)
    print(change.new)
dropdown.observe(dropdown_eventhandler, names='value')
display(dropdown)
# Out:
# Dropdown(description='Choose folder:', options=('.DS_Store', '.ipynb_checkpoints', '2017-02-04--10-14-06--00-1…
# 2017-02-04--10-14-06--00-16-35--BC

# %%
os.chdir(directory + 'call_segments/' +file[0])
pngs=glob.glob('*.png')

# %%
len(pngs)
# Out:
# 8

# %%
import matplotlib.image as mpimg
from IPython.display import Image

#f, axarr = plt.subplots(len(pngs),1)

fig=plt.figure()  

for p in list(range(len(pngs))):
    print(p)
    pic=pngs[p]
    img = Image(pic)
    fig.add_subplot(len(pngs),1,p+1)
    plt.imshow(img)
plt.show()
# Out:
# 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-1f0bd24cee02> in <module>
#      12     img = Image(pic)
#      13     fig.add_subplot(len(pngs),1,p+1)
# ---> 14     plt.imshow(img)
#      15 plt.show()
#
# /Library/Python/3.8/site-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, data, **kwargs)
#    2722         filternorm=True, filterrad=4.0, resample=None, url=None,
#    2723         data=None, **kwargs):
# -> 2724     __ret = gca().imshow(
#    2725         X, cmap=cmap, norm=norm, aspect=aspect,
#    2726         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# /Library/Python/3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# /Library/Python/3.8/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, filternorm, filterrad, resample, url, **kwargs)
#    5521                               resample=resample, **kwargs)
#    5522
# -> 5523         im.set_data(X)
#    5524         im.set_alpha(alpha)
#    5525         if im.get_clip_path() is None:
#
# /Library/Python/3.8/site-packages/matplotlib/image.py in set_data(self, A)
#     698         if (self._A.dtype != np.uint8 and
#     699                 not np.can_cast(self._A.dtype, float, "same_kind")):
# --> 700             raise TypeError("Image data of dtype {} cannot be converted to "
#     701                             "float".format(self._A.dtype))
#     702
#
# TypeError: Image data of dtype object cannot be converted to float

# %%
img = mpimg.imread(pic)

# %%
from IPython.display import Image
Image(pic)
